# %%
import pandas as pd
import sqlalchemy

DB_NAME = "clinic_care"
DB_USER = "postgres"
DB_PASS = "asdfasdf"
DB_HOST = "localhost"
DB_PORT = "5432"

df = pd.read_csv('i-icd-codes.csv', sep='|', index_col=None)[0:100]

database_url = f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

engine = sqlalchemy.create_engine(database_url)

df.to_sql('codes', con=engine, if_exists='append', index=False)
# Out:
# 100
